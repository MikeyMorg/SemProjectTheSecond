# %% [markdown]
# ## SQL Implementation of our database

# %% [markdown]
# # Import

# %%
import duckdb
from pathlib import Path

# %% [markdown]
# Query

# %%
cwd = Path().cwd()
project = cwd.parent
train = Path('data/train_data.csv')
test = Path('data/test_data_competition.csv')

train_df = project / train
test_df = project / test

if not train_df.exists() or not test_df.exists():
    raise FileNotFoundError("Data files not found.")

con = duckdb.connect(':memory:')

con.execute(f"CREATE TABLE train_df AS SELECT * FROM read_csv_auto('{train_df}')")
con.execute(f"CREATE TABLE test_df AS SELECT * FROM read_csv_auto('{test_df}')")

# Preview the data
print("Training data:")
print(con.execute("SELECT * FROM train_df LIMIT 5").df())
print("\nTest data:")
print(con.execute("SELECT * FROM test_df LIMIT 5").df())
# Out:
# Training data:
#                                            Person ID  Gender  Age  \
# 0  d29d53701d3c859e29e1b90028eec1ca8e2f29439198b6...    Male   62
# 1  71a1c003a2b855d85582c8f6c7648c49d3fe836408a7e1...  Female   35
# 2  86e50149658661312a9e0b35558d84f6c6d3da797f552a...  Female   50
# 3  093434a3ee9e0a010bb2c2aae06c2614dd24894062a1ca...    Male   38
# 4  e3d6c4d4599e00882384ca981ee287ed961fa5f3828e2a...  Female   34
#
#       Occupation  Sleep Duration (hours)  Quality of Sleep (scale: 1-10)  \
# 0        Student                5.802690                        9.684249
# 1   Manual Labor                7.928079                        4.589872
# 2  Office Worker                4.425595                        6.809697
# 3  Office Worker                9.031985                        4.682931
# 4        Student                8.719110                        6.729776
#
#    Physical Activity Level (minutes/day)  Stress Level (scale: 1-10)  \
# 0                              26.361925                    9.247187
# 1                             111.302978                    3.092288
# 2                              28.559919                    5.168146
# 3                              76.911892                    6.037287
# 4                              11.742485                    2.029544
#
#   BMI Category Blood Pressure (systolic/diastolic)  Heart Rate (bpm)  \
# 0   Overweight                              131/78         88.434966
# 1   Overweight                              117/69         62.090257
# 2        Obese                              135/86         94.422789
# 3   Overweight                              119/69         80.149192
# 4       Normal                              117/69         74.926656
#
#     Daily Steps Sleep Disorder
# 0  12135.856393    No Disorder
# 1  19871.474804       Insomnia
# 2  18754.661163    No Disorder
# 3  12658.283618    No Disorder
# 4  17742.211473       Insomnia
#
# Test data:
#                                            Person ID  Gender  Age  \
# 0  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...  Female   43
# 1  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    Male   44
# 2  ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...    Male   67
# 3  7902699be42c8a8e46fbbb4501726517e86b22c56a189f...    Male   22
# 4  2c624232cdd221771294dfbb310aca000a0df6ac8b66b6...    Male   49
#
#       Occupation  Sleep Duration (hours)  Quality of Sleep (scale: 1-10)  \
# 0        Retired                4.098740                        5.136837
# 1        Retired                5.827224                        5.844961
# 2        Retired                8.755386                        9.705185
# 3  Office Worker                5.116560                        5.849033
# 4  Office Worker               10.768926                        6.309661
#
#    Physical Activity Level (minutes/day)  Stress Level (scale: 1-10)  \
# 0                              41.562939                    4.810686
# 1                             102.406454                    4.194374
# 2                              19.066119                    3.956095
# 3                              25.933787                    6.246805
# 4                              50.548678                    8.043279
#
#   BMI Category Blood Pressure (systolic/diastolic)  Heart Rate (bpm)  \
# 0        Obese                              131/86         83.493435
# 1  Underweight                              122/70         82.562315
# 2   Overweight                              133/78         98.935420
# 3        Obese                              121/70         63.613424
# 4        Obese                              134/87         59.978015
#
#     Daily Steps
# 0  17891.445565
# 1   2995.370789
# 2  14425.255066
# 3  15341.764037
# 4  18927.980081

# %%
# Filter by Sleep Disorder (returns as pandas DataFrames)
no_dis = con.execute("SELECT * FROM train_df WHERE \"Sleep Disorder\" = 'No Disorder'").df()
insomnia = con.execute("SELECT * FROM train_df WHERE \"Sleep Disorder\" = 'Insomnia'").df()
apnea = con.execute("SELECT * FROM train_df WHERE \"Sleep Disorder\" = 'Sleep Apnea'").df()

# %%
print(no_dis.info())
print(no_dis.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Person ID                              70 non-null     object
#  1   Gender                                 70 non-null     object
#  2   Age                                    70 non-null     int64
#  3   Occupation                             70 non-null     object
#  4   Sleep Duration (hours)                 70 non-null     float64
#  5   Quality of Sleep (scale: 1-10)         70 non-null     float64
#  6   Physical Activity Level (minutes/day)  70 non-null     float64
#  7   Stress Level (scale: 1-10)             70 non-null     float64
#  8   BMI Category                           70 non-null     object
#  9   Blood Pressure (systolic/diastolic)    70 non-null     object
#  10  Heart Rate (bpm)                       70 non-null     float64
#  11  Daily Steps                            70 non-null     float64
#  12  Sleep Disorder                         70 non-null     object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 7.2+ KB
# None
#                                                 Person ID Gender        Age  \
# count                                                  70     70  70.000000
# unique                                                 70      2        NaN
# top     d29d53701d3c859e29e1b90028eec1ca8e2f29439198b6...   Male        NaN
# freq                                                    1     36        NaN
# mean                                                  NaN    NaN  41.171429
# std                                                   NaN    NaN  14.248286
# min                                                   NaN    NaN  18.000000
# 25%                                                   NaN    NaN  29.000000
# 50%                                                   NaN    NaN  39.500000
# 75%                                                   NaN    NaN  50.000000
# max                                                   NaN    NaN  72.000000
#
#        Occupation  Sleep Duration (hours)  Quality of Sleep (scale: 1-10)  \
# count          70               70.000000                       70.000000
# unique          4                     NaN                             NaN
# top       Student                     NaN                             NaN
# freq           22                     NaN                             NaN
# mean          NaN                7.992489                        5.846040
# std           NaN                2.026129                        2.109366
# min           NaN                4.099805                        0.952464
# 25%           NaN                6.445810                        4.437603
# 50%           NaN                8.207361                        5.859555
# 75%           NaN                9.526284                        7.152107
# max           NaN               12.056268                       10.181282
#
#         Physical Activity Level (minutes/day)  Stress Level (scale: 1-10)  \
# count                               70.000000                   70.000000
# unique                                    NaN                         NaN
# top                                       NaN                         NaN
# freq                                      NaN                         NaN
# mean                                66.423630                    5.876609
# std                                 35.690856                    3.228989
# min                                  9.584213                    0.952482
# 25%                                 32.343712                    3.010532
# 50%                                 67.226149                    5.964977
# 75%                                 96.690751                    9.196613
# max                                121.595011                   10.419793
#
#        BMI Category Blood Pressure (systolic/diastolic)  Heart Rate (bpm)  \
# count            70                                  70         70.000000
# unique            4                                  66               NaN
# top      Overweight                              112/60               NaN
# freq             24                                   2               NaN
# mean            NaN                                 NaN         76.993738
# std             NaN                                 NaN         15.523978
# min             NaN                                 NaN         49.291095
# 25%             NaN                                 NaN         63.559430
# 50%             NaN                                 NaN         77.869451
# 75%             NaN                                 NaN         90.754893
# max             NaN                                 NaN        102.046253
#
#          Daily Steps Sleep Disorder
# count      70.000000             70
# unique           NaN              1
# top              NaN    No Disorder
# freq             NaN             70
# mean    10759.976061            NaN
# std      5258.277948            NaN
# min      2066.202591            NaN
# 25%      6110.149535            NaN
# 50%     11028.510209            NaN
# 75%     14917.918204            NaN
# max     19581.377351            NaN
